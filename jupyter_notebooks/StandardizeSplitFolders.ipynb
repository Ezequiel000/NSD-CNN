# %% [markdown]
# #Modules

# %%
import os
import numpy as np
import pandas as pd
import h5py
LABLE_FILE = 'C:/Users/007303173/Documents/Independent_Study_Project/nsd_data/ppdata/subj01/behav/responses.tsv'
FMRI_DIR = 'C:/Users/007303173/Documents/Independent_Study_Project/nsd_data/GLM-fmri-data/subj01'
FMRI_DIR_STND = 'C:/Users/007303173/Documents/Independent_Study_Project/nsd_data/standardized-betas/subj01'
TRIAL_PER_SESS = 750
POSITIVE_DIRECTORY =  'C:/Users/007303173/Documents/Independent_Study_Project/nsd_data/standardized-betas/subj01/isCorrect/'
NEGATIVE_DIRECTORY =  'C:/Users/007303173/Documents/Independent_Study_Project/nsd_data/standardized-betas/subj01/isNotCorrect/'

# !pip install line_profiler
# %load_ext line_profiler

# %% [markdown]
# Here we get the name of all files in the directory containgn the betas

# %%
  # returns a list of all files in the directory to be standardized
def getDirFiles(FMRI_DIR):
     files = [f for f in os.listdir(FMRI_DIR) if 
              os.path.isfile(os.path.join(FMRI_DIR, f)) and
              f[-5:] == '.hdf5']
     files.sort()                          
     return files

# %% [markdown]
# This shows each scan session is comprised of 750 scans. Each scan is of size (83, 104, 81)

# %%
files = getDirFiles(FMRI_DIR)
f = files[0]
print(f)
f = os.path.join(FMRI_DIR, f)
scan1=[]
with h5py.File(f, "r") as file:
    print(file.keys())
    print(file['betas'].shape)
    scan1 = np.array(file['betas'])
print(scan1.shape[0])

# %%
print(scan1.max())
print(scan1.min())
print(scan1.mean(0)[59,27,63])
mean = np.mean(scan1,axis=0)
print(mean[59,27,63])

# %%
print('filtering labels...')
res = pd.read_csv(LABLE_FILE, sep='\t')
res = pd.DataFrame(res)
res = res.loc[res['SESSION'] == 1]
res = res.loc[res['ISOLD'] == 1]
res = res.loc[res['ISCORRECT'] == 0]
res = res.filter(items = ['ISCORRECT'] )
res.shape
# for index, row in res.iterrows():
#     print(index, row['ISCORRECT'])
# Out:
# filtering labels...
# (20, 1)

# %% [markdown]
# #Standardize all betas in the directory
#
# ---

# %%
class StandardizeDirectory:
  def __init__(self, loading_dir, dumping_dir, response_file):
    self.ld = loading_dir
    self.dd = dumping_dir
    self.rs = response_file
    self.index = 0
    self.offset = TRIAL_PER_SESS
    self.fmri_files = self.getDirFiles()
    self.file_handlers ={}
    self.open_files()

  def __del__(self):
    for value in self.file_handlers.items():
      value.close()
  # returns a list of all files in the directory to be standardized
  def getDirFiles(self):
     files = [f for f in os.listdir(self.ld) if 
              os.path.isfile(os.path.join(self.ld, f)) and
              f[-5:] == '.hdf5']
     files.sort()                          
     return files               

  def open_files(self): 
    for file_name in self.fmri_files:
      path = os.path.join(FMRI_DIR, file_name)
      self.file_handlers[file_name] = h5py.File(path, 'r')

  # Input: path of the responses.tsv file
  # Output: dictionary of indexes as keys with a corresponding class lable
  # in put the sesh number to filter , pass the session as an argument 
  def get_labels(self):
      print('filtering labels...')
      res = pd.read_csv(self.rs, sep='\t')
      res = pd.DataFrame(res)
      res = res.loc[res['SESSION'] <= 37]
      res = res.loc[res['ISOLD'] == 1]
      res = res.loc[res['ISCORRECT'] > -1]
      res = res.filter(items = ['ISCORRECT'] )
      return res

  def dump(self):
 
    responses = self.get_labels()
    size_of_positive = 0
    size_of_negative = 0
    for session in self.file_handlers:
      print('standardizing betas from session '+ session)
      sesh = np.array(self.file_handlers[session]['betas'])
      print("loaded the sesh")
      positive_path = os.path.join(POSITIVE_DIRECTORY,('stnd-'+session))
      negative_path = os.path.join(NEGATIVE_DIRECTORY,('stnd-'+session))
      print('getting z-score' )
      mean = sesh.mean(0)
      std = sesh.std(0)
      std = np.where(std == 0, 1, std)
      standardized = (sesh-mean)/std
      mean=0
      std=0
      sesh=0
      print('z-score complete' )
      positive_betas = np.empty(shape = (0, 83, 104, 81))
      negative_betas = np.empty(shape = (0, 83, 104, 81))

      for index, row in responses.iterrows(): # this iters through the list of ID which is the index of imaghes from 0-29999
        if index >= self.offset:
          self.index = self.offset
          self.offset += TRIAL_PER_SESS
          pos = h5py.File(positive_path, 'a')
          pos.create_dataset('betas',data = positive_betas)
          pos.close
          neg = h5py.File(negative_path, 'a')
          neg.create_dataset('betas',data = negative_betas)
          neg.close
          break
        elif row['ISCORRECT'] == 1:
          print("Expanding  Positive array for sample #",index )
          expanded = np.expand_dims(standardized[(index-self.index)], axis=0)
          positive_betas = np.concatenate((positive_betas, expanded), axis=0)
          print("concatenating finalized sample #",index )
          responses = responses.drop(index)
         
        elif row['ISCORRECT'] == 0:
          print("Expanding  Negative array for sample",index )
          expanded = np.expand_dims(standardized[(index-self.index)], axis=0)
          negative_betas = np.concatenate((negative_betas, expanded), axis=0)
          print("concatenating finalized sample #",index )
          responses = responses.drop(index)

# %%
st = StandardizeDirectory(FMRI_DIR, FMRI_DIR_STND, LABLE_FILE)
st.dump()
# Out:
# filtering labels...
# standardizing betas from session betas_session01.hdf5
# loaded the sesh
# getting z-score
# z-score complete
# Expanding  Positive array for sample # 45
# concatenating finalized sample # 45
# Expanding  Positive array for sample # 68
# concatenating finalized sample # 68
# Expanding  Positive array for sample # 90
# concatenating finalized sample # 90
# Expanding  Positive array for sample # 107
# concatenating finalized sample # 107
# Expanding  Positive array for sample # 121
# concatenating finalized sample # 121
# Expanding  Positive array for sample # 123
# concatenating finalized sample # 123
# Expanding  Positive array for sample # 148
# concatenating finalized sample # 148
# Expanding  Positive array for sample # 153
# concatenating finalized sample # 153
# Expanding  Positive array for sample # 154
# concatenating finalized sample # 154
# Expanding  Positive array for sample # 172
# concatenating finalized sample # 172
# Expanding  Negative array for sample 180
# concatenating finalized sample # 180
# Expanding  Positive array for sample # 187
# concatenating finalized sample # 187
# Expanding  Positive array for sample # 188
# concatenating finalized sample # 188
# Expanding  Positive array for sample # 189
# concatenating finalized sample # 189
# Expanding  Negative array for sample 191
# concatenating finalized sample # 191
# Expanding  Positive array for sample # 196
# concatenating finalized sample # 196
# Expanding  Positive array for sample # 212
# concatenating finalized sample # 212
# Expanding  Positive array for sample # 213
# concatenating finalized sample # 213
# Expanding  Negative array for sample 219
# concatenating finalized sample # 219
# Expanding  Positive array for sample # 222
# concatenating finalized sample # 222
# Expanding  Positive array for sample # 224
# concatenating finalized sample # 224
# Expanding  Positive array for sample # 226
# concatenating finalized sample # 226
# Expanding  Negative array for sample 229
# concatenating finalized sample # 229
# Expanding  Positive array for sample # 241
# concatenating finalized sample # 241
# Expanding  Positive array for sample # 248
# concatenating finalized sample # 248
# Expanding  Negative array for sample 263
# concatenating finalized sample # 263
# Expanding  Positive array for sample # 264
# concatenating finalized sample # 264
# Expanding  Positive array for sample # 265
# concatenating finalized sample # 265
# Expanding  Positive array for sample # 270
# concatenating finalized sample # 270
# Expanding  Positive array for sample # 278
# concatenating finalized sample # 278
# Expanding  Negative array for sample 280
# concatenating finalized sample # 280
# Expanding  Positive array for sample # 282
# concatenating finalized sample # 282
# Expanding  Positive array for sample # 283
# concatenating finalized sample # 283
# Expanding  Positive array for sample # 285
# concatenating finalized sample # 285
# Expanding  Positive array for sample # 287
# concatenating finalized sample # 287
# Expanding  Positive array for sample # 288
# concatenating finalized sample # 288
# Expanding  Positive array for sample # 294
# concatenating finalized sample # 294
# Expanding  Negative array for sample 310
# concatenating finalized sample # 310
# Expanding  Positive array for sample # 311
# concatenating finalized sample # 311
# Expanding  Negative array for sample 320
# concatenating finalized sample # 320
# Expanding  Positive array for sample # 328
# concatenating finalized sample # 328
# Expanding  Positive array for sample # 333
# concatenating finalized sample # 333
# Expanding  Negative array for sample 342
# concatenating finalized sample # 342
# Expanding  Positive array for sample # 352
# concatenating finalized sample # 352
# Expanding  Negative array for sample 353
# concatenating finalized sample # 353
# Expanding  Positive array for sample # 355
# concatenating finalized sample # 355
# Expanding  Positive array for sample # 361
# concatenating finalized sample # 361
# Expanding  Positive array for sample # 362
# concatenating finalized sample # 362
# Expanding  Positive array for sample # 363
# concatenating finalized sample # 363
# Expanding  Positive array for sample # 368
# concatenating finalized sample # 368
# Expanding  Positive array for sample # 369
# concatenating finalized sample # 369
# Expanding  Positive array for sample # 372
# concatenating finalized sample # 372
# Expanding  Positive array for sample # 374
# concatenating finalized sample # 374
# Expanding  Positive array for sample # 375
# concatenating finalized sample # 375
# Expanding  Negative array for sample 378
# concatenating finalized sample # 378
# Expanding  Positive array for sample # 381
# concatenating finalized sample # 381
# Expanding  Negative array for sample 383
# concatenating finalized sample # 383
# Expanding  Positive array for sample # 386
# concatenating finalized sample # 386
# Expanding  Positive array for sample # 387
# concatenating finalized sample # 387
# Expanding  Positive array for sample # 388
# concatenating finalized sample # 388
# Expanding  Negative array for sample 390
# concatenating finalized sample # 390
# Expanding  Positive array for sample # 391
# concatenating finalized sample # 391
# Expanding  Positive array for sample # 393
# concatenating finalized sample # 393
# Expanding  Positive array for sample # 400
# concatenating finalized sample # 400
# Expanding  Positive array for sample # 404
# concatenating finalized sample # 404
# Expanding  Positive array for sample # 405
# concatenating finalized sample # 405
# Expanding  Positive array for sample # 408
# concatenating finalized sample # 408
# Expanding  Positive array for sample # 409
# concatenating finalized sample # 409
# Expanding  Positive array for sample # 415
# concatenating finalized sample # 415
# Expanding  Positive array for sample # 418
# concatenating finalized sample # 418
# Expanding  Negative array for sample 419
# concatenating finalized sample # 419
# Expanding  Negative array for sample 420
# concatenating finalized sample # 420
# Expanding  Positive array for sample # 423
# concatenating finalized sample # 423
# Expanding  Positive array for sample # 426
# concatenating finalized sample # 426
# Expanding  Positive array for sample # 427
# concatenating finalized sample # 427
# Expanding  Positive array for sample # 432
# concatenating finalized sample # 432
# Expanding  Positive array for sample # 437
# concatenating finalized sample # 437
# Expanding  Positive array for sample # 439
# concatenating finalized sample # 439
# Expanding  Positive array for sample # 445
# concatenating finalized sample # 445
# Expanding  Positive array for sample # 447
# concatenating finalized sample # 447
# Expanding  Positive array for sample # 449
# concatenating finalized sample # 449
# Expanding  Positive array for sample # 451
# concatenating finalized sample # 451
# Expanding  Positive array for sample # 453
# concatenating finalized sample # 453
# Expanding  Positive array for sample # 456
# concatenating finalized sample # 456
# Expanding  Positive array for sample # 457
# concatenating finalized sample # 457
# Expanding  Positive array for sample # 459
# concatenating finalized sample # 459
# Expanding  Positive array for sample # 462
# concatenating finalized sample # 462
# Expanding  Negative array for sample 464
# concatenating finalized sample # 464
# Expanding  Positive array for sample # 477
# concatenating finalized sample # 477
# Expanding  Positive array for sample # 480
# concatenating finalized sample # 480
# Expanding  Positive array for sample # 481
# concatenating finalized sample # 481
# Expanding  Positive array for sample # 485
# concatenating finalized sample # 485
# Expanding  Negative array for sample 487
# concatenating finalized sample # 487
# Expanding  Positive array for sample # 488
# concatenating finalized sample # 488
# Expanding  Positive array for sample # 489
# concatenating finalized sample # 489
# Expanding  Positive array for sample # 491
# concatenating finalized sample # 491
# Expanding  Positive array for sample # 492
# concatenating finalized sample # 492
# Expanding  Positive array for sample # 493
# concatenating finalized sample # 493
# Expanding  Positive array for sample # 500
# concatenating finalized sample # 500
# Expanding  Positive array for sample # 501
# concatenating finalized sample # 501
# Expanding  Positive array for sample # 502
# concatenating finalized sample # 502
# Expanding  Positive array for sample # 503
# concatenating finalized sample # 503
# Expanding  Positive array for sample # 506
# concatenating finalized sample # 506
# Expanding  Positive array for sample # 508
# concatenating finalized sample # 508
# Expanding  Positive array for sample # 512
# concatenating finalized sample # 512
# Expanding  Positive array for sample # 513
# concatenating finalized sample # 513
# Expanding  Positive array for sample # 516
# concatenating finalized sample # 516
# Expanding  Positive array for sample # 517
# concatenating finalized sample # 517
# Expanding  Positive array for sample # 534
# concatenating finalized sample # 534
# Expanding  Positive array for sample # 538
# concatenating finalized sample # 538
# Expanding  Positive array for sample # 539
# concatenating finalized sample # 539
# Expanding  Positive array for sample # 546
# concatenating finalized sample # 546
# Expanding  Positive array for sample # 549
# concatenating finalized sample # 549
# Expanding  Positive array for sample # 550
# concatenating finalized sample # 550
# Expanding  Positive array for sample # 553
# concatenating finalized sample # 553
# Expanding  Positive array for sample # 554
# concatenating finalized sample # 554
# Expanding  Positive array for sample # 560
# concatenating finalized sample # 560
# Expanding  Positive array for sample # 563
# concatenating finalized sample # 563
# Expanding  Positive array for sample # 565
# concatenating finalized sample # 565
# Expanding  Positive array for sample # 570
# concatenating finalized sample # 570
# Expanding  Positive array for sample # 573
# concatenating finalized sample # 573
# Expanding  Positive array for sample # 575
# concatenating finalized sample # 575
# Expanding  Positive array for sample # 576
# concatenating finalized sample # 576
# Expanding  Positive array for sample # 584
# concatenating finalized sample # 584
# Expanding  Positive array for sample # 587
# concatenating finalized sample # 587
# Expanding  Positive array for sample # 589
# concatenating finalized sample # 589
# Expanding  Negative array for sample 593
# concatenating finalized sample # 593
# Expanding  Positive array for sample # 598
# concatenating finalized sample # 598
# Expanding  Positive array for sample # 599
# concatenating finalized sample # 599
# Expanding  Positive array for sample # 608
# concatenating finalized sample # 608
# Expanding  Negative array for sample 609
# concatenating finalized sample # 609
# Expanding  Positive array for sample # 611
# concatenating finalized sample # 611
# Expanding  Positive array for sample # 620
# concatenating finalized sample # 620
# Expanding  Positive array for sample # 621
# concatenating finalized sample # 621
# Expanding  Positive array for sample # 624
# concatenating finalized sample # 624
# Expanding  Positive array for sample # 632
# concatenating finalized sample # 632
# Expanding  Positive array for sample # 636
# concatenating finalized sample # 636
# Expanding  Positive array for sample # 639
# concatenating finalized sample # 639
# Expanding  Positive array for sample # 640
# concatenating finalized sample # 640
# Expanding  Negative array for sample 646
# concatenating finalized sample # 646
# Expanding  Positive array for sample # 650
# concatenating finalized sample # 650
# Expanding  Positive array for sample # 656
# concatenating finalized sample # 656
# Expanding  Positive array for sample # 658
# concatenating finalized sample # 658
# Expanding  Positive array for sample # 659
# concatenating finalized sample # 659
# Expanding  Positive array for sample # 664
# concatenating finalized sample # 664
# Expanding  Positive array for sample # 667
# concatenating finalized sample # 667
# Expanding  Positive array for sample # 674
# concatenating finalized sample # 674
# Expanding  Positive array for sample # 676
# concatenating finalized sample # 676
# Expanding  Positive array for sample # 678
# concatenating finalized sample # 678
# Expanding  Positive array for sample # 679
# concatenating finalized sample # 679
# Expanding  Positive array for sample # 683
# concatenating finalized sample # 683
# Expanding  Positive array for sample # 684
# concatenating finalized sample # 684
# Expanding  Positive array for sample # 686
# concatenating finalized sample # 686
# Expanding  Positive array for sample # 689
# concatenating finalized sample # 689
# Expanding  Positive array for sample # 691
# concatenating finalized sample # 691
# Expanding  Positive array for sample # 692
# concatenating finalized sample # 692
# Expanding  Positive array for sample # 699
# concatenating finalized sample # 699
# Expanding  Positive array for sample # 709
# concatenating finalized sample # 709
# Expanding  Positive array for sample # 714
# concatenating finalized sample # 714
# Expanding  Positive array for sample # 719
# concatenating finalized sample # 719
# Expanding  Positive array for sample # 720
# concatenating finalized sample # 720
# Expanding  Positive array for sample # 724
# concatenating finalized sample # 724
# Expanding  Positive array for sample # 726
# concatenating finalized sample # 726
# Expanding  Positive array for sample # 727
# concatenating finalized sample # 727
# Expanding  Positive array for sample # 737
# concatenating finalized sample # 737
# Expanding  Positive array for sample # 738
# concatenating finalized sample # 738
# Expanding  Positive array for sample # 740
# concatenating finalized sample # 740
# standardizing betas from session betas_session02.hdf5
# loaded the sesh
# getting z-score
# z-score complete
# Expanding  Negative array for sample 753
# concatenating finalized sample # 753
# Expanding  Positive array for sample # 758
# concatenating finalized sample # 758
# Expanding  Negative array for sample 761
# concatenating finalized sample # 761
# Expanding  Negative array for sample 764
# concatenating finalized sample # 764
# Expanding  Positive array for sample # 769
# concatenating finalized sample # 769
# Expanding  Negative array for sample 773
# concatenating finalized sample # 773
# Expanding  Positive array for sample # 774
# concatenating finalized sample # 774
# Expanding  Negative array for sample 775
# concatenating finalized sample # 775
# Expanding  Negative array for sample 776
# concatenating finalized sample # 776
# Expanding  Negative array for sample 779
# concatenating finalized sample # 779
# Expanding  Positive array for sample # 789
# concatenating finalized sample # 789
# Expanding  Positive array for sample # 794
# concatenating finalized sample # 794
# Expanding  Positive array for sample # 795
# concatenating finalized sample # 795
# Expanding  Positive array for sample # 796
# concatenating finalized sample # 796
# Expanding  Positive array for sample # 797
# concatenating finalized sample # 797
# Expanding  Positive array for sample # 798
# concatenating finalized sample # 798
# Expanding  Positive array for sample # 799
# concatenating finalized sample # 799
# Expanding  Positive array for sample # 800
# concatenating finalized sample # 800
# Expanding  Negative array for sample 812
# concatenating finalized sample # 812
# Expanding  Positive array for sample # 821
# concatenating finalized sample # 821
# Expanding  Positive array for sample # 822
# concatenating finalized sample # 822
# Expanding  Positive array for sample # 825
# concatenating finalized sample # 825
# Expanding  Positive array for sample # 826
# concatenating finalized sample # 826
# Expanding  Positive array for sample # 828
# concatenating finalized sample # 828
# Expanding  Negative array for sample 833
# concatenating finalized sample # 833
# Expanding  Negative array for sample 835
# concatenating finalized sample # 835
# Expanding  Positive array for sample # 836
# concatenating finalized sample # 836
# Expanding  Positive array for sample # 844
# concatenating finalized sample # 844
# Expanding  Positive array for sample # 845
# concatenating finalized sample # 845
# Expanding  Positive array for sample # 849
# concatenating finalized sample # 849
# Expanding  Negative array for sample 858
# concatenating finalized sample # 858
# Expanding  Positive array for sample # 859
# concatenating finalized sample # 859
# Expanding  Positive array for sample # 860
# concatenating finalized sample # 860
# Expanding  Positive array for sample # 861
# concatenating finalized sample # 861
# Expanding  Positive array for sample # 866
# concatenating finalized sample # 866
# Expanding  Negative array for sample 867
# concatenating finalized sample # 867
# Expanding  Positive array for sample # 870
# concatenating finalized sample # 870
# Expanding  Positive array for sample # 871
# concatenating finalized sample # 871
# Expanding  Positive array for sample # 872
# concatenating finalized sample # 872
# Expanding  Positive array for sample # 874
# concatenating finalized sample # 874
# Expanding  Positive array for sample # 875
# concatenating finalized sample # 875
# Expanding  Positive array for sample # 879
# concatenating finalized sample # 879
# Expanding  Positive array for sample # 883
# concatenating finalized sample # 883
# Expanding  Positive array for sample # 885
# concatenating finalized sample # 885
# Expanding  Positive array for sample # 890
# concatenating finalized sample # 890
# Expanding  Negative array for sample 891
# concatenating finalized sample # 891
# Expanding  Positive array for sample # 894
# concatenating finalized sample # 894
# Expanding  Positive array for sample # 895
# concatenating finalized sample # 895
# Expanding  Positive array for sample # 896
# concatenating finalized sample # 896
# Expanding  Positive array for sample # 898
# concatenating finalized sample # 898
# Expanding  Positive array for sample # 899
# concatenating finalized sample # 899
# Expanding  Positive array for sample # 904
# concatenating finalized sample # 904
# Expanding  Negative array for sample 905
# concatenating finalized sample # 905
# Expanding  Positive array for sample # 906
# concatenating finalized sample # 906
# Expanding  Positive array for sample # 910
# concatenating finalized sample # 910
# Expanding  Positive array for sample # 911
# concatenating finalized sample # 911
# Expanding  Positive array for sample # 912
# concatenating finalized sample # 912
# Expanding  Positive array for sample # 914
# concatenating finalized sample # 914
# Expanding  Positive array for sample # 920
# concatenating finalized sample # 920
# Expanding  Positive array for sample # 921
# concatenating finalized sample # 921
# Expanding  Positive array for sample # 923
# concatenating finalized sample # 923
# Expanding  Negative array for sample 927
# concatenating finalized sample # 927
# Expanding  Positive array for sample # 928
# concatenating finalized sample # 928
# Expanding  Positive array for sample # 930
# concatenating finalized sample # 930
# Expanding  Positive array for sample # 931
# concatenating finalized sample # 931
# Expanding  Positive array for sample # 935
# concatenating finalized sample # 935
# Expanding  Positive array for sample # 937
# concatenating finalized sample # 937
# Expanding  Positive array for sample # 938
# concatenating finalized sample # 938
# Expanding  Positive array for sample # 940
# concatenating finalized sample # 940
# Expanding  Negative array for sample 941
# concatenating finalized sample # 941
# Expanding  Negative array for sample 948
# concatenating finalized sample # 948
# Expanding  Positive array for sample # 949
# concatenating finalized sample # 949
# Expanding  Negative array for sample 953
# concatenating finalized sample # 953
# Expanding  Negative array for sample 954
# concatenating finalized sample # 954
# Expanding  Positive array for sample # 963
# concatenating finalized sample # 963
# Expanding  Positive array for sample # 964
# concatenating finalized sample # 964
# Expanding  Negative array for sample 965
# concatenating finalized sample # 965
# Expanding  Positive array for sample # 967
# concatenating finalized sample # 967
# Expanding  Positive array for sample # 973
# concatenating finalized sample # 973
# Expanding  Negative array for sample 978
# concatenating finalized sample # 978
# Expanding  Positive array for sample # 980
# concatenating finalized sample # 980
# Expanding  Negative array for sample 982
# concatenating finalized sample # 982
# Expanding  Negative array for sample 983
# concatenating finalized sample # 983
# Expanding  Negative array for sample 987
# concatenating finalized sample # 987
# Expanding  Negative array for sample 989
# concatenating finalized sample # 989
# Expanding  Positive array for sample # 990
# concatenating finalized sample # 990
# Expanding  Positive array for sample # 992
# concatenating finalized sample # 992
# Expanding  Positive array for sample # 994
# concatenating finalized sample # 994
# Expanding  Negative array for sample 995
# concatenating finalized sample # 995
# Expanding  Positive array for sample # 999
# concatenating finalized sample # 999
# Expanding  Positive array for sample # 1000
# concatenating finalized sample # 1000
# Expanding  Negative array for sample 1001
# concatenating finalized sample # 1001
# Expanding  Positive array for sample # 1002
# concatenating finalized sample # 1002
# Expanding  Positive array for sample # 1006
# concatenating finalized sample # 1006
# Expanding  Positive array for sample # 1012
# concatenating finalized sample # 1012
# Expanding  Positive array for sample # 1015
# concatenating finalized sample # 1015
# Expanding  Negative array for sample 1016
# concatenating finalized sample # 1016
# Expanding  Negative array for sample 1030
# concatenating finalized sample # 1030
# Expanding  Negative array for sample 1032
# concatenating finalized sample # 1032
# Expanding  Negative array for sample 1036
# concatenating finalized sample # 1036
# Expanding  Negative array for sample 1044
# concatenating finalized sample # 1044
# Expanding  Positive array for sample # 1052
# concatenating finalized sample # 1052
# Expanding  Negative array for sample 1056
# concatenating finalized sample # 1056
# Expanding  Negative array for sample 1058
# concatenating finalized sample # 1058
# Expanding  Positive array for sample # 1061
# concatenating finalized sample # 1061
# Expanding  Positive array for sample # 1063
# concatenating finalized sample # 1063
# Expanding  Positive array for sample # 1067
# concatenating finalized sample # 1067
# Expanding  Positive array for sample # 1069
# concatenating finalized sample # 1069
# Expanding  Positive array for sample # 1070
# concatenating finalized sample # 1070
# Expanding  Positive array for sample # 1073
# concatenating finalized sample # 1073
# Expanding  Positive array for sample # 1076
# concatenating finalized sample # 1076
# Expanding  Negative array for sample 1078
# concatenating finalized sample # 1078
# Expanding  Negative array for sample 1079
# concatenating finalized sample # 1079
# Expanding  Negative array for sample 1082
# concatenating finalized sample # 1082
# Expanding  Positive array for sample # 1085
# concatenating finalized sample # 1085
# Expanding  Negative array for sample 1086
# concatenating finalized sample # 1086
# Expanding  Positive array for sample # 1092
# concatenating finalized sample # 1092
# Expanding  Positive array for sample # 1095
# concatenating finalized sample # 1095
# Expanding  Negative array for sample 1096
# concatenating finalized sample # 1096
# Expanding  Positive array for sample # 1097
# concatenating finalized sample # 1097
# Expanding  Negative array for sample 1113
# concatenating finalized sample # 1113
# Expanding  Positive array for sample # 1117
# concatenating finalized sample # 1117
# Expanding  Negative array for sample 1126
# concatenating finalized sample # 1126
# Expanding  Negative array for sample 1131
# concatenating finalized sample # 1131
# Expanding  Positive array for sample # 1133
# concatenating finalized sample # 1133
# Expanding  Positive array for sample # 1135
# concatenating finalized sample # 1135
# Expanding  Positive array for sample # 1144
# concatenating finalized sample # 1144
# Expanding  Positive array for sample # 1148
# concatenating finalized sample # 1148
# Expanding  Positive array for sample # 1151
# concatenating finalized sample # 1151
# Expanding  Negative array for sample 1161
# concatenating finalized sample # 1161
# Expanding  Positive array for sample # 1162
# concatenating finalized sample # 1162
# Expanding  Negative array for sample 1165
# concatenating finalized sample # 1165
# Expanding  Positive array for sample # 1168
# concatenating finalized sample # 1168
# Expanding  Positive array for sample # 1171
# concatenating finalized sample # 1171
# Expanding  Positive array for sample # 1172
# concatenating finalized sample # 1172
# Expanding  Positive array for sample # 1180
# concatenating finalized sample # 1180
# Expanding  Positive array for sample # 1184
# concatenating finalized sample # 1184
# Expanding  Positive array for sample # 1186
# concatenating finalized sample # 1186
# Expanding  Positive array for sample # 1188
# concatenating finalized sample # 1188
# Expanding  Negative array for sample 1193
# concatenating finalized sample # 1193
# Expanding  Positive array for sample # 1195
# concatenating finalized sample # 1195
# Expanding  Negative array for sample 1198
# concatenating finalized sample # 1198
# Expanding  Positive array for sample # 1201
# concatenating finalized sample # 1201
# Expanding  Positive array for sample # 1206
# concatenating finalized sample # 1206
# Expanding  Positive array for sample # 1210
# concatenating finalized sample # 1210
# Expanding  Negative array for sample 1211
# concatenating finalized sample # 1211
# Expanding  Positive array for sample # 1218
# concatenating finalized sample # 1218
# Expanding  Positive array for sample # 1219
# concatenating finalized sample # 1219
# Expanding  Positive array for sample # 1221
# concatenating finalized sample # 1221
# Expanding  Positive array for sample # 1228
# concatenating finalized sample # 1228
# Expanding  Negative array for sample 1233
# concatenating finalized sample # 1233
# Expanding  Positive array for sample # 1240
# concatenating finalized sample # 1240
# Expanding  Positive array for sample # 1245
# concatenating finalized sample # 1245
# Expanding  Positive array for sample # 1246
# concatenating finalized sample # 1246
# Expanding  Positive array for sample # 1248
# concatenating finalized sample # 1248
# Expanding  Positive array for sample # 1252
# concatenating finalized sample # 1252
# Expanding  Negative array for sample 1253
# concatenating finalized sample # 1253
# Expanding  Positive array for sample # 1257
# concatenating finalized sample # 1257
# Expanding  Negative array for sample 1259
# concatenating finalized sample # 1259
# Expanding  Positive array for sample # 1260
# concatenating finalized sample # 1260
# Expanding  Positive array for sample # 1264
# concatenating finalized sample # 1264
# Expanding  Positive array for sample # 1266
# concatenating finalized sample # 1266
# Expanding  Positive array for sample # 1268
# concatenating finalized sample # 1268
# Expanding  Positive array for sample # 1270
# concatenating finalized sample # 1270
# Expanding  Positive array for sample # 1271
# concatenating finalized sample # 1271
# Expanding  Positive array for sample # 1272
# concatenating finalized sample # 1272
# Expanding  Positive array for sample # 1273
# concatenating finalized sample # 1273
# Expanding  Positive array for sample # 1277
# concatenating finalized sample # 1277
# Expanding  Negative array for sample 1278
# concatenating finalized sample # 1278
# Expanding  Positive array for sample # 1280
# concatenating finalized sample # 1280
# Expanding  Negative array for sample 1281
# concatenating finalized sample # 1281
# Expanding  Positive array for sample # 1282
# concatenating finalized sample # 1282
# Expanding  Positive array for sample # 1283
# concatenating finalized sample # 1283
# Expanding  Positive array for sample # 1288
# concatenating finalized sample # 1288
# Expanding  Positive array for sample # 1291
# concatenating finalized sample # 1291
# Expanding  Positive array for sample # 1293
# concatenating finalized sample # 1293
# Expanding  Positive array for sample # 1294
# concatenating finalized sample # 1294
# Expanding  Positive array for sample # 1298
# concatenating finalized sample # 1298
# Expanding  Positive array for sample # 1299
# concatenating finalized sample # 1299
# Expanding  Positive array for sample # 1300
# concatenating finalized sample # 1300
# Expanding  Positive array for sample # 1301
# concatenating finalized sample # 1301
# Expanding  Positive array for sample # 1303
# concatenating finalized sample # 1303
# Expanding  Positive array for sample # 1305
# concatenating finalized sample # 1305
# Expanding  Positive array for sample # 1308
# concatenating finalized sample # 1308
# Expanding  Positive array for sample # 1309
# concatenating finalized sample # 1309
# Expanding  Positive array for sample # 1311
# concatenating finalized sample # 1311
# Expanding  Positive array for sample # 1312
# concatenating finalized sample # 1312
# Expanding  Positive array for sample # 1317
# concatenating finalized sample # 1317
# Expanding  Positive array for sample # 1324
# concatenating finalized sample # 1324
# Expanding  Positive array for sample # 1325
# concatenating finalized sample # 1325
# Expanding  Positive array for sample # 1326
# concatenating finalized sample # 1326
# Expanding  Positive array for sample # 1328
# concatenating finalized sample # 1328
# Expanding  Positive array for sample # 1329
# concatenating finalized sample # 1329
# Expanding  Positive array for sample # 1332
# concatenating finalized sample # 1332
# Expanding  Positive array for sample # 1333
# concatenating finalized sample # 1333
# Expanding  Positive array for sample # 1341
# concatenating finalized sample # 1341
# Expanding  Positive array for sample # 1343
# concatenating finalized sample # 1343
# Expanding  Positive array for sample # 1347
# concatenating finalized sample # 1347
# Expanding  Positive array for sample # 1348
# concatenating finalized sample # 1348
# Expanding  Positive array for sample # 1350
# concatenating finalized sample # 1350
# Expanding  Positive array for sample # 1353
# concatenating finalized sample # 1353
# Expanding  Positive array for sample # 1358
# concatenating finalized sample # 1358
# Expanding  Negative array for sample 1359
# concatenating finalized sample # 1359
# Expanding  Positive array for sample # 1362
# concatenating finalized sample # 1362
# Expanding  Positive array for sample # 1363
# concatenating finalized sample # 1363
# Expanding  Positive array for sample # 1364
# concatenating finalized sample # 1364
# Expanding  Positive array for sample # 1366
# concatenating finalized sample # 1366
# Expanding  Positive array for sample # 1368
# concatenating finalized sample # 1368
# Expanding  Positive array for sample # 1369
# concatenating finalized sample # 1369
# Expanding  Negative array for sample 1374
# concatenating finalized sample # 1374
# Expanding  Positive array for sample # 1375
# concatenating finalized sample # 1375
# Expanding  Positive array for sample # 1377
# concatenating finalized sample # 1377
# Expanding  Positive array for sample # 1379
# concatenating finalized sample # 1379
# Expanding  Positive array for sample # 1381
# concatenating finalized sample # 1381
# Expanding  Positive array for sample # 1384
# concatenating finalized sample # 1384
# Expanding  Positive array for sample # 1391
# concatenating finalized sample # 1391
# Expanding  Positive array for sample # 1394
# concatenating finalized sample # 1394
# Expanding  Positive array for sample # 1397
# concatenating finalized sample # 1397
# Expanding  Positive array for sample # 1401
# concatenating finalized sample # 1401
# Expanding  Positive array for sample # 1405
# concatenating finalized sample # 1405
# Expanding  Positive array for sample # 1406
# concatenating finalized sample # 1406
# Expanding  Positive array for sample # 1410
# concatenating finalized sample # 1410
# Expanding  Positive array for sample # 1413
# concatenating finalized sample # 1413
# Expanding  Positive array for sample # 1415
# concatenating finalized sample # 1415
# Expanding  Negative array for sample 1417
# concatenating finalized sample # 1417
# Expanding  Positive array for sample # 1419
# concatenating finalized sample # 1419
# Expanding  Positive array for sample # 1420
# concatenating finalized sample # 1420
# Expanding  Positive array for sample # 1425
# concatenating finalized sample # 1425
# Expanding  Negative array for sample 1427
# concatenating finalized sample # 1427
# Expanding  Positive array for sample # 1428
# concatenating finalized sample # 1428
# Expanding  Positive array for sample # 1446
# concatenating finalized sample # 1446
# Expanding  Positive array for sample # 1450
# concatenating finalized sample # 1450
# Expanding  Positive array for sample # 1451
# concatenating finalized sample # 1451
# Expanding  Positive array for sample # 1454
# concatenating finalized sample # 1454
# Expanding  Positive array for sample # 1460
# concatenating finalized sample # 1460
# Expanding  Positive array for sample # 1464
# concatenating finalized sample # 1464
# Expanding  Positive array for sample # 1466
# concatenating finalized sample # 1466
# Expanding  Positive array for sample # 1468
# concatenating finalized sample # 1468
# Expanding  Positive array for sample # 1469
# concatenating finalized sample # 1469
# Expanding  Positive array for sample # 1473
# concatenating finalized sample # 1473
# Expanding  Positive array for sample # 1477
# concatenating finalized sample # 1477
# Expanding  Positive array for sample # 1478
# concatenating finalized sample # 1478
# Expanding  Positive array for sample # 1479
# concatenating finalized sample # 1479
# Expanding  Positive array for sample # 1480
# concatenating finalized sample # 1480
# Expanding  Positive array for sample # 1483
# concatenating finalized sample # 1483
# Expanding  Positive array for sample # 1486
# concatenating finalized sample # 1486
# Expanding  Positive array for sample # 1488
# concatenating finalized sample # 1488
# Expanding  Positive array for sample # 1489
# concatenating finalized sample # 1489
# Expanding  Positive array for sample # 1496
# concatenating finalized sample # 1496
# standardizing betas from session betas_session03.hdf5
# loaded the sesh
# getting z-score
# z-score complete
# Expanding  Negative array for sample 1502
# concatenating finalized sample # 1502
# Expanding  Positive array for sample # 1503
# concatenating finalized sample # 1503
# Expanding  Positive array for sample # 1504
# concatenating finalized sample # 1504
# Expanding  Positive array for sample # 1506
# concatenating finalized sample # 1506
# Expanding  Negative array for sample 1509
# concatenating finalized sample # 1509
# Expanding  Positive array for sample # 1513
# concatenating finalized sample # 1513
# Expanding  Negative array for sample 1517
# concatenating finalized sample # 1517
# Expanding  Positive array for sample # 1521
# concatenating finalized sample # 1521
# Expanding  Negative array for sample 1522
# concatenating finalized sample # 1522
# Expanding  Negative array for sample 1531
# concatenating finalized sample # 1531
# Expanding  Negative array for sample 1532
# concatenating finalized sample # 1532
# Expanding  Negative array for sample 1534
# concatenating finalized sample # 1534
# Expanding  Positive array for sample # 1536
# concatenating finalized sample # 1536
# Expanding  Positive array for sample # 1538
# concatenating finalized sample # 1538
# Expanding  Positive array for sample # 1539
# concatenating finalized sample # 1539
# Expanding  Positive array for sample # 1543
# concatenating finalized sample # 1543
# Expanding  Positive array for sample # 1544
# concatenating finalized sample # 1544
# Expanding  Positive array for sample # 1547
# concatenating finalized sample # 1547
# Expanding  Positive array for sample # 1551
# concatenating finalized sample # 1551
# Expanding  Negative array for sample 1552
# concatenating finalized sample # 1552
# Expanding  Positive array for sample # 1554
# concatenating finalized sample # 1554
# Expanding  Positive array for sample # 1555
# concatenating finalized sample # 1555
# Expanding  Positive array for sample # 1558
# concatenating finalized sample # 1558
# Expanding  Positive array for sample # 1563
# concatenating finalized sample # 1563
# Expanding  Positive array for sample # 1564
# concatenating finalized sample # 1564
# Expanding  Positive array for sample # 1568
# concatenating finalized sample # 1568
# Expanding  Positive array for sample # 1570
# concatenating finalized sample # 1570
# Expanding  Positive array for sample # 1572
# concatenating finalized sample # 1572
# Expanding  Positive array for sample # 1574
# concatenating finalized sample # 1574
# Expanding  Negative array for sample 1577
# concatenating finalized sample # 1577
# Expanding  Positive array for sample # 1579
# concatenating finalized sample # 1579
# Expanding  Positive array for sample # 1581
# concatenating finalized sample # 1581
# Expanding  Negative array for sample 1586
# concatenating finalized sample # 1586
# Expanding  Positive array for sample # 1587
# concatenating finalized sample # 1587
# Expanding  Negative array for sample 1592
# concatenating finalized sample # 1592
# Expanding  Positive array for sample # 1595
# concatenating finalized sample # 1595
# Expanding  Negative array for sample 1600
# concatenating finalized sample # 1600
# concatenating finalized sample # 1867
# Expanding  Positive array for sample # 1868
# concatenating finalized sample # 1868
# Expanding  Positive array for sample # 1873
# concatenating finalized sample # 1873
# Expanding  Positive array for sample # 1875
# concatenating finalized sample # 1875
# Expanding  Positive array for sample # 1878
# concatenating finalized sample # 1878
# Expanding  Positive array for sample # 1885
# concatenating finalized sample # 1885
# Expanding  Positive array for sample # 1886
# concatenating finalized sample # 1886
# Expanding  Positive array for sample # 1889
# concatenating finalized sample # 1889
# Expanding  Positive array for sample # 1892
# concatenating finalized sample # 1892
# Expanding  Positive array for sample # 1894
# concatenating finalized sample # 1894
# Expanding  Negative array for sample 1897
# concatenating finalized sample # 1897
# Expanding  Positive array for sample # 1902
# concatenating finalized sample # 1902
# Expanding  Positive array for sample # 1905
# concatenating finalized sample # 1905
# Expanding  Positive array for sample # 1907
# concatenating finalized sample # 1907
# Expanding  Positive array for sample # 1909
# concatenating finalized sample # 1909
# Expanding  Positive array for sample # 1910
# concatenating finalized sample # 1910
# Expanding  Positive array for sample # 1911
# concatenating finalized sample # 1911
# Expanding  Positive array for sample # 1912
# concatenating finalized sample # 1912
# Expanding  Positive array for sample # 1914
# concatenating finalized sample # 1914
# Expanding  Positive array for sample # 1924
# concatenating finalized sample # 1924
# Expanding  Positive array for sample # 1927
# concatenating finalized sample # 1927
# Expanding  Positive array for sample # 1928
# concatenating finalized sample # 1928
# Expanding  Positive array for sample # 1935
# concatenating finalized sample # 1935
# Expanding  Negative array for sample 1939
# concatenating finalized sample # 1939
# Expanding  Positive array for sample # 1951
# concatenating finalized sample # 1951
# Expanding  Positive array for sample # 1952
# concatenating finalized sample # 1952
# Expanding  Positive array for sample # 1955
# concatenating finalized sample # 1955
# Expanding  Positive array for sample # 1958
# concatenating finalized sample # 1958
# Expanding  Positive array for sample # 1960
# concatenating finalized sample # 1960
# Expanding  Positive array for sample # 1963
# concatenating finalized sample # 1963
# Expanding  Positive array for sample # 1965
# concatenating finalized sample # 1965
# Expanding  Positive array for sample # 1968
# concatenating finalized sample # 1968
# Expanding  Positive array for sample # 1973
# concatenating finalized sample # 1973
# Expanding  Positive array for sample # 1975
# concatenating finalized sample # 1975
# Expanding  Positive array for sample # 1976
# concatenating finalized sample # 1976
# Expanding  Positive array for sample # 1979
# concatenating finalized sample # 1979
# Expanding  Positive array for sample # 1980
# concatenating finalized sample # 1980
# Expanding  Positive array for sample # 1981
# concatenating finalized sample # 1981
# Expanding  Positive array for sample # 1983
# concatenating finalized sample # 1983
# Expanding  Positive array for sample # 1985
# concatenating finalized sample # 1985
# Expanding  Positive array for sample # 1988
# concatenating finalized sample # 1988
# Expanding  Positive array for sample # 1991
# concatenating finalized sample # 1991
# Expanding  Positive array for sample # 1996
# concatenating finalized sample # 1996
# Expanding  Positive array for sample # 1997
# concatenating finalized sample # 1997
# ...
# Expanding  Positive array for sample # 27538
# concatenating finalized sample # 27538
# Expanding  Positive array for sample # 27539
# concatenating finalized sample # 27539
# Expanding  Positive array for sample # 27540
# concatenating finalized sample # 27540
# Expanding  Positive array for sample # 27541
# concatenating finalized sample # 27541
# Expanding  Positive array for sample # 27542
# concatenating finalized sample # 27542
# Expanding  Positive array for sample # 27543
# concatenating finalized sample # 27543
# Expanding  Positive array for sample # 27544
# concatenating finalized sample # 27544
# Expanding  Negative array for sample 27545
# concatenating finalized sample # 27545
# Expanding  Negative array for sample 27546
# concatenating finalized sample # 27546
# Expanding  Positive array for sample # 27547
# concatenating finalized sample # 27547
# Expanding  Negative array for sample 27548
# concatenating finalized sample # 27548
# Expanding  Positive array for sample # 27549
# concatenating finalized sample # 27549
# Expanding  Positive array for sample # 27550
# concatenating finalized sample # 27550
# Expanding  Positive array for sample # 27551
# concatenating finalized sample # 27551
# Expanding  Positive array for sample # 27552
# concatenating finalized sample # 27552
# Expanding  Positive array for sample # 27555
# concatenating finalized sample # 27555
# Expanding  Negative array for sample 27556
# concatenating finalized sample # 27556
# Expanding  Positive array for sample # 27558
# concatenating finalized sample # 27558
# Expanding  Positive array for sample # 27559
# concatenating finalized sample # 27559
# Expanding  Positive array for sample # 27560
# concatenating finalized sample # 27560
# Expanding  Positive array for sample # 27561
# concatenating finalized sample # 27561
# Expanding  Positive array for sample # 27562
# concatenating finalized sample # 27562
# Expanding  Positive array for sample # 27563
# concatenating finalized sample # 27563
# Expanding  Negative array for sample 27564
# concatenating finalized sample # 27564
# Expanding  Positive array for sample # 27565
# concatenating finalized sample # 27565
# Expanding  Positive array for sample # 27566
# concatenating finalized sample # 27566
# Expanding  Negative array for sample 27567
# concatenating finalized sample # 27567
# Expanding  Positive array for sample # 27568
# concatenating finalized sample # 27568
# Expanding  Positive array for sample # 27569
# concatenating finalized sample # 27569
# Expanding  Negative array for sample 27570
# concatenating finalized sample # 27570
# Expanding  Negative array for sample 27571
# concatenating finalized sample # 27571
# Expanding  Positive array for sample # 27572
# concatenating finalized sample # 27572
# Expanding  Positive array for sample # 27573
# concatenating finalized sample # 27573
# Expanding  Positive array for sample # 27574
# concatenating finalized sample # 27574
# Expanding  Positive array for sample # 27575
# concatenating finalized sample # 27575
# Expanding  Positive array for sample # 27576
# concatenating finalized sample # 27576
# Expanding  Positive array for sample # 27578
# concatenating finalized sample # 27578
# Expanding  Positive array for sample # 27579
# concatenating finalized sample # 27579
# Expanding  Positive array for sample # 27581
# concatenating finalized sample # 27581
# Expanding  Positive array for sample # 27583
# concatenating finalized sample # 27583
# Expanding  Positive array for sample # 27584
# concatenating finalized sample # 27584
# Expanding  Positive array for sample # 27585
# concatenating finalized sample # 27585
# Expanding  Positive array for sample # 27586
# concatenating finalized sample # 27586
# Expanding  Negative array for sample 27587
# concatenating finalized sample # 27587
# Expanding  Positive array for sample # 27589
# concatenating finalized sample # 27589
# Expanding  Positive array for sample # 27590
# concatenating finalized sample # 27590
# Expanding  Negative array for sample 27591
# concatenating finalized sample # 27591
# Expanding  Positive array for sample # 27592
# concatenating finalized sample # 27592
# Expanding  Positive array for sample # 27593
# concatenating finalized sample # 27593
# Expanding  Positive array for sample # 27594
# concatenating finalized sample # 27594
